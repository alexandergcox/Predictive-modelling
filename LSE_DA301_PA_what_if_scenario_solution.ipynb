# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
# # Course 301: Advanced Analytics for Organisational Impact

# %% [markdown]
# ## Practical activity: Completing a what-if scenario analysis

# %% [markdown]
# **This is the solution to the activity.**
#
# You’re working at a financial analysis firm that specialises in risk management to support clients' stock trading. To help a client make an investment decision, you have been asked to run return-on-investment (ROI) scenarios. The client asks for ROI on its investment over the next six years, and you have been given the following inputs:
# - Number of shares: 500
# - Buying price per share: 10
# - Annual dividends: 500
# - Selling price: 15
# - Other annual costs: 125
# - Target annualised ROI: 7.5%
# - Annualised $ROI = [(1+(ROI)^{(1/n)}-1] ×100%$
#
# Using these inputs, you need to calculate ROI for the swix years that the investor intends to hold on to their stock, and then run a what-if analysis using different values as inputs to mimic a good or bad economy for the client’s investment.

# %% [markdown]
# ## 1. Prepare your workstation

# %%
# Import the necessary libraries.
import pandas as pd
import random
import matplotlib.pyplot as plt
from dataclasses import dataclass
from sensitivity import SensitivityAnalyzer

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 2. Specify the model inputs and create a class

# %%
# Create a class and instance.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()

# View the output.
model_data
# Out:
# ModelInputs(share_no=500, buying_price=10, dividend=500, selling_price=15, costs=125)

# %% [markdown]
# ## 3. Create a function to calculate ROI

# %%
# Function to calculate ROI. 
def roi_per_year(data: ModelInputs):
    year = 0
    prior_roi = 0
    
    while year < 6:
        year = year + 1
        # print(year).
        net_return = (data.selling_price - data.buying_price)\
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no

        roi = prior_roi + ((net_return)/(cost_of_investment))*100
        print(f'The ROI at year {year} is {roi:,.0f}%.')
        
        prior_roi = roi
        
    return roi

# View output.
roi_per_year(model_data)
# Out:
# The ROI at year 1 is 57%.
# The ROI at year 2 is 115%.
# The ROI at year 3 is 172%.
# The ROI at year 4 is 230%.
# The ROI at year 5 is 287%.
# The ROI at year 6 is 345%.
# 344.99999999999994

# %%
# Function to create a DataFrame as df: 
def roi_per_year_df(data: ModelInputs):
    year = 0
    prior_roi = 0
    df_data_tups = []
    
    for year in range(6):
        year = year + 1
        net_return = (data.selling_price - data.buying_price)\
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no
        roi = prior_roi + ((net_return)/(cost_of_investment))*100
        # print(f'The ROI at year {year} is {roi:,.0f}%.').
        
        prior_roi = roi 
        # Save the results in a tuple for later building the DataFrame.
        df_data_tups.append((year, roi))
        # Now create the DataFrame.
        df = pd.DataFrame(df_data_tups, columns=['Year', 'ROI in %'])
        
    return df

# View the DataFrame.
roi_per_year_df(model_data)
# Out:
#    Year  ROI in %
# 0     1      57.5
# 1     2     115.0
# 2     3     172.5
# 3     4     230.0
# 4     5     287.5
# 5     6     345.0

# %% [markdown]
# ## 4. Create a function to show ROI for each year and a single year

# %%
# Function to give the annual ROI for each year. 
def annualized_roi_per_year(data: ModelInputs):
    year = 0
    prior_roi = 0

    for year in range(6):
        year = year + 1
        # print(year).
        net_return = (data.selling_price - data.buying_price)\
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no
        roi = prior_roi + ((net_return)/(cost_of_investment))*100 
        print(f"ROI :{roi}")
        
        # annual_roi = [((1 + (roi/100))**(1/year)-1)*100].
        annual_roi = ((1 + (roi/100))**(1/year)-1)*100
        print(f'The annualized ROI at year {year} is {annual_roi}%.')
        prior_roi = roi 
        
    return annual_roi

# View the output.
annualized_roi_per_year(model_data)
# Out:
# ROI :57.49999999999999
# The annualized ROI at year 1 is 57.49999999999999%.
# ROI :114.99999999999999
# The annualized ROI at year 2 is 46.628782986151805%.
# ROI :172.49999999999997
# The annualized ROI at year 3 is 39.67612206238158%.
# ROI :229.99999999999997
# The annualized ROI at year 4 is 34.78094125129469%.
# ROI :287.49999999999994
# The annualized ROI at year 5 is 31.1155923590563%.
# ROI :344.99999999999994
# The annualized ROI at year 6 is 28.25077608160358%.
# 28.25077608160358

# %%
# Function to return annualised ROI for a single year. 
def anl_roi_per_year(data: ModelInputs, print_output=True):
    year = 0
    prior_roi = 0
    
    if print_output:
        # \n makes a blank line in the output.
        print('Anuual ROI over time:') 
        
    while year < 10:
        year = year + 1
        net_return = (data.selling_price - data.buying_price)\
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no
        
        # Cost of investment is simply the buying price of each 
        # share multiplied by the number of shares purchased, 
        # e.g. 10 shares at $5 means the cost of investment is £50.
        roi = prior_roi + ((net_return)/(cost_of_investment))*100
        print(f"roi :{roi}")
        
        anl_roi = ((1 + (roi/100))**(1/year)-1)*100
        
        return anl_roi
    
# View the output
anl_roi_per_year(model_data)
# Out:
# Anuual ROI over time:
# roi :57.49999999999999
# 57.49999999999999

# %% [markdown]
# ## 5. Run the model based on some changes
#  - Initial investment increases by 10% and decreases by 10%.
#  - Buying price per share increases by 15% and decreases by 10%.
#  - Selling price per share increases by 20% and decreases by 15%.
#  - Annual dividend increases by 25% and decreases by 20%.

# %% [markdown]
# ### a)    Initial investment increases by 10% and decreases by 10%.

# %%
# Investment = buying price * share.
# Note: Assuming that instead of the investment, the variable to be used is the share number.

# %%
# Buying price per share increases by 10%.
@dataclass
class ModelInputs:
    share_no : int = 550
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 57%.
# The ROI at year 2 is 114%.
# The ROI at year 3 is 170%.
# The ROI at year 4 is 227%.
# The ROI at year 5 is 284%.
# The ROI at year 6 is 341%.
# 340.90909090909093

# %%
# Buying share per share decreases by 10%.
@dataclass
class ModelInputs:
    share_no : int = 450
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 58%.
# The ROI at year 2 is 117%.
# The ROI at year 3 is 175%.
# The ROI at year 4 is 233%.
# The ROI at year 5 is 292%.
# The ROI at year 6 is 350%.
# 350.0

# %% [markdown]
# ### b) Buying price per share increases by 15% and decreases by 10%

# %%
# Buying price per share increases by 15%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 11.5
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 37%.
# The ROI at year 2 is 74%.
# The ROI at year 3 is 111%.
# The ROI at year 4 is 148%.
# The ROI at year 5 is 185%.
# The ROI at year 6 is 222%.
# 221.7391304347826

# %%
# Buying price per share decreases by 10%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 9
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 75%.
# The ROI at year 2 is 150%.
# The ROI at year 3 is 225%.
# The ROI at year 4 is 300%.
# The ROI at year 5 is 375%.
# The ROI at year 6 is 450%.
# 450.0

# %% [markdown]
# ### c) Selling price per share increases by 20% and decreases by 15%.

# %%
# Selling price per share increases by 20%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 18
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 88%.
# The ROI at year 2 is 175%.
# The ROI at year 3 is 262%.
# The ROI at year 4 is 350%.
# The ROI at year 5 is 438%.
# The ROI at year 6 is 525%.
# 525.0

# %%
# Selling price per share decreases by 15%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 12.75
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 35%.
# The ROI at year 2 is 70%.
# The ROI at year 3 is 105%.
# The ROI at year 4 is 140%.
# The ROI at year 5 is 175%.
# The ROI at year 6 is 210%.
# 210.0

# %% [markdown]
# ### d) Annual dividend increases by 25% and decreases by 20%.

# %%
# Annual dividend increases by 25%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 625
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 60%.
# The ROI at year 2 is 120%.
# The ROI at year 3 is 180%.
# The ROI at year 4 is 240%.
# The ROI at year 5 is 300%.
# The ROI at year 6 is 360%.
# 360.0

# %%
# Annual dividend decreases by 20%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 400
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 56%.
# The ROI at year 2 is 111%.
# The ROI at year 3 is 167%.
# The ROI at year 4 is 222%.
# The ROI at year 5 is 278%.
# The ROI at year 6 is 333%.
# 333.00000000000006

# %% [markdown]
# ## 6. Create a 'good' and 'bad' scenario

# %%
# Create a good and bad scenario.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data
# Out:
# ModelInputs(share_no=500, buying_price=10, dividend=500, selling_price=15, costs=125)

# %%
bad_economy_data = ModelInputs(
    share_no = 100,
    buying_price = 600,
    dividend = 200,
    selling_price = 200,
    costs = 900)

good_economy_data = ModelInputs(
    share_no= 800,
    buying_price= 30,
    dividend= 600,
    selling_price= 45,
    costs= 100)

cases = {
    'Bad': bad_economy_data,
    # Original inputs were set to assume a normal economy.
    'Normal': model_data, 
    'Good': good_economy_data}

for case_type, case_inputs in cases.items():
    ytr = anl_roi_per_year(case_inputs, print_output=False)
    
    print(f'Annualized ROI would be {ytr} in case of {case_type} economy.')
# Out:
# roi :-67.83333333333333
# Annualized ROI would be -67.83333333333333 in case of Bad economy.
# roi :57.49999999999999
# Annualized ROI would be 57.49999999999999 in case of Normal economy.
# roi :52.083333333333336
# Annualized ROI would be 52.08333333333335 in case of Good economy.

# %% [markdown]
# ## 7. Perform a what-if scenario

# %%
# Run a what-if analysis.
def analyzer_what_if(    
    share_no  = 500,
    buying_price = 10,
    dividend = 500,
    selling_price = 15,
    costs = 125):
    data = ModelInputs(
        share_no=share_no, 
        buying_price=buying_price, 
        dividend=dividend, 
        selling_price=selling_price,  
        costs=costs)
    
    return annualized_roi_per_year(data)

analyzer_what_if()
# Out:
# ROI :57.49999999999999
# The annualized ROI at year 1 is 57.49999999999999%.
# ROI :114.99999999999999
# The annualized ROI at year 2 is 46.628782986151805%.
# ROI :172.49999999999997
# The annualized ROI at year 3 is 39.67612206238158%.
# ROI :229.99999999999997
# The annualized ROI at year 4 is 34.78094125129469%.
# ROI :287.49999999999994
# The annualized ROI at year 5 is 31.1155923590563%.
# ROI :344.99999999999994
# The annualized ROI at year 6 is 28.25077608160358%.
# 28.25077608160358

# %%
def analyzer_what_if(    
    share_no  = 500,
    buying_price = 10,
    dividend = 500,
    selling_price = 15,
    costs = 125):
    data = ModelInputs(
        share_no=share_no, 
        buying_price=buying_price, 
        dividend=dividend, 
        selling_price=selling_price,  
        costs=costs)
    
    return anl_roi_per_year(data)

analyzer_what_if()
# Out:
# Anuual ROI over time:
# roi :57.49999999999999
# 57.49999999999999

# %%
# It is certainly possible to specify all these through hard-coding but 
# using list comprehensions makes it easier to adjust.
sensitivity_values = {
    'share_no': [i * 100 for i in range(4, 8)],
    'buying_price': [i*10 for i in range(4, 8)],
    'dividend': [i *100 for i in range(1, 4)],
    'selling_price': [i *10 for i in range(10, 25, 5)],
    'costs': [i * 100 for i in range(3, 10)],
    # 'interest_rate': [i/100 for i in range(3, 8)],
    # 'desired_cash': [i * 100000 for i in range(10, 26, 5)]
}

sensitivity_values
# Out:
# {'share_no': [400, 500, 600, 700],
#  'buying_price': [40, 50, 60, 70],
#  'dividend': [100, 200, 300],
#  'selling_price': [100, 150, 200],
#  'costs': [300, 400, 500, 600, 700, 800, 900]}

# %%
# Run the Python’s SensitivityAnalyzer with the all the assigned inputs:
sa = SensitivityAnalyzer(
    sensitivity_values,
    analyzer_what_if,
    result_name='Annual ROI',
    reverse_colors=True,
    grid_size=3)
# Out:
#  56%|███████████████████████████████████████████▏                                 | 565/1008 [00:00<00:00, 2844.51it/s]
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.125
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :146.875
# Anuual ROI over time:
# roi :146.25
# Anuual ROI over time:
# roi :145.625
# Anuual ROI over time:
# roi :145.0
# Anuual ROI over time:
# roi :273.75
# Anuual ROI over time:
# roi :273.125
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :271.875
# Anuual ROI over time:
# roi :271.25
# Anuual ROI over time:
# roi :270.625
# Anuual ROI over time:
# roi :270.0
# Anuual ROI over time:
# roi :398.75
# Anuual ROI over time:
# roi :398.125
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :396.875
# Anuual ROI over time:
# roi :396.25
# Anuual ROI over time:
# roi :395.625
# Anuual ROI over time:
# roi :395.0
# Anuual ROI over time:
# roi :149.375
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.125
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :146.875
# Anuual ROI over time:
# roi :146.25
# Anuual ROI over time:
# roi :145.625
# Anuual ROI over time:
# roi :274.375
# Anuual ROI over time:
# roi :273.75
# Anuual ROI over time:
# roi :273.125
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :271.875
# Anuual ROI over time:
# roi :271.25
# Anuual ROI over time:
# roi :270.625
# Anuual ROI over time:
# roi :399.375
# Anuual ROI over time:
# roi :398.75
# Anuual ROI over time:
# roi :398.125
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :396.875
# Anuual ROI over time:
# roi :396.25
# Anuual ROI over time:
# roi :395.625
# Anuual ROI over time:
# roi :150.0
# Anuual ROI over time:
# roi :149.375
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.125
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :146.875
# Anuual ROI over time:
# roi :146.25
# Anuual ROI over time:
# roi :275.0
# Anuual ROI over time:
# roi :274.375
# Anuual ROI over time:
# roi :273.75
# Anuual ROI over time:
# roi :273.125
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :271.875
# Anuual ROI over time:
# roi :271.25
# Anuual ROI over time:
# roi :400.0
# Anuual ROI over time:
# roi :399.375
# Anuual ROI over time:
# roi :398.75
# Anuual ROI over time:
# roi :398.125
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :396.875
# Anuual ROI over time:
# roi :396.25
# Anuual ROI over time:
# roi :99.0
# Anuual ROI over time:
# roi :98.5
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.5
# Anuual ROI over time:
# roi :97.0
# Anuual ROI over time:
# roi :96.5
# Anuual ROI over time:
# roi :96.0
# Anuual ROI over time:
# roi :199.0
# Anuual ROI over time:
# roi :198.5
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.5
# Anuual ROI over time:
# roi :197.0
# Anuual ROI over time:
# roi :196.5
# Anuual ROI over time:
# roi :196.0
# Anuual ROI over time:
# roi :299.0
# Anuual ROI over time:
# roi :298.5
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.5
# Anuual ROI over time:
# roi :297.0
# Anuual ROI over time:
# roi :296.5
# Anuual ROI over time:
# roi :296.0
# Anuual ROI over time:
# roi :99.5
# Anuual ROI over time:
# roi :99.0
# Anuual ROI over time:
# roi :98.5
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.5
# Anuual ROI over time:
# roi :97.0
# Anuual ROI over time:
# roi :96.5
# Anuual ROI over time:
# roi :199.5
# Anuual ROI over time:
# roi :199.0
# Anuual ROI over time:
# roi :198.5
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.5
# Anuual ROI over time:
# roi :197.0
# Anuual ROI over time:
# roi :196.5
# Anuual ROI over time:
# roi :299.5
# Anuual ROI over time:
# roi :299.0
# Anuual ROI over time:
# roi :298.5
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.5
# Anuual ROI over time:
# roi :297.0
# Anuual ROI over time:
# roi :296.5
# Anuual ROI over time:
# roi :100.0
# Anuual ROI over time:
# roi :99.5
# Anuual ROI over time:
# roi :99.0
# Anuual ROI over time:
# roi :98.5
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.5
# Anuual ROI over time:
# roi :97.0
# Anuual ROI over time:
# roi :200.0
# Anuual ROI over time:
# roi :199.5
# Anuual ROI over time:
# roi :199.0
# Anuual ROI over time:
# roi :198.5
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.5
# Anuual ROI over time:
# roi :197.0
# Anuual ROI over time:
# roi :300.0
# Anuual ROI over time:
# roi :299.5
# Anuual ROI over time:
# roi :299.0
# Anuual ROI over time:
# roi :298.5
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.5
# Anuual ROI over time:
# roi :297.0
# Anuual ROI over time:
# roi :65.83333333333333
# Anuual ROI over time:
# roi :65.41666666666667
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :64.58333333333334
# Anuual ROI over time:
# roi :64.16666666666667
# Anuual ROI over time:
# roi :63.74999999999999
# Anuual ROI over time:
# roi :63.33333333333333
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :147.91666666666669
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :147.08333333333334
# Anuual ROI over time:
# roi :146.66666666666666
# Anuual ROI over time:
# roi :232.50000000000003
# Anuual ROI over time:
# roi :232.08333333333334
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.25
# Anuual ROI over time:
# roi :230.83333333333331
# Anuual ROI over time:
# roi :230.41666666666666
# Anuual ROI over time:
# roi :229.99999999999997
# Anuual ROI over time:
# roi :66.25
# Anuual ROI over time:
# roi :65.83333333333333
# Anuual ROI over time:
# roi :65.41666666666667
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :64.58333333333334
# Anuual ROI over time:
# roi :64.16666666666667
# Anuual ROI over time:
# roi :63.74999999999999
# Anuual ROI over time:
# roi :149.58333333333334
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :147.91666666666669
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :147.08333333333334
# Anuual ROI over time:
# roi :232.91666666666666
# Anuual ROI over time:
# roi :232.50000000000003
# Anuual ROI over time:
# roi :232.08333333333334
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.25
# Anuual ROI over time:
# roi :230.83333333333331
# Anuual ROI over time:
# roi :230.41666666666666
# Anuual ROI over time:
# roi :66.66666666666666
# Anuual ROI over time:
# roi :66.25
# Anuual ROI over time:
# roi :65.83333333333333
# Anuual ROI over time:
# roi :65.41666666666667
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :64.58333333333334
# Anuual ROI over time:
# roi :64.16666666666667
# Anuual ROI over time:
# roi :150.0
# Anuual ROI over time:
# roi :149.58333333333334
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :147.91666666666669
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :233.33333333333334
# Anuual ROI over time:
# roi :232.91666666666666
# Anuual ROI over time:
# roi :232.50000000000003
# Anuual ROI over time:
# roi :232.08333333333334
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.25
# Anuual ROI over time:
# roi :230.83333333333331
# Anuual ROI over time:
# roi :42.142857142857146
# Anuual ROI over time:
# roi :41.785714285714285
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.07142857142857
# Anuual ROI over time:
# roi :40.714285714285715
# Anuual ROI over time:
# roi :40.35714285714286
# Anuual ROI over time:
# roi :40.0
# Anuual ROI over time:
# roi :113.57142857142857
# Anuual ROI over time:
# roi :113.21428571428571
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.5
# Anuual ROI over time:
# roi :112.14285714285714
# Anuual ROI over time:
# roi :111.78571428571429
# Anuual ROI over time:
# roi :111.42857142857143
# Anuual ROI over time:
# roi :185.0
# Anuual ROI over time:
# roi :184.64285714285717
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :183.92857142857142
# Anuual ROI over time:
# roi :183.57142857142856
# Anuual ROI over time:
# roi :183.2142857142857
# Anuual ROI over time:
# roi :182.85714285714286
# Anuual ROI over time:
# roi :42.5
# Anuual ROI over time:
# roi :42.142857142857146
# Anuual ROI over time:
# roi :41.785714285714285
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.07142857142857
# Anuual ROI over time:
# roi :40.714285714285715
# Anuual ROI over time:
# roi :40.35714285714286
# Anuual ROI over time:
# roi :113.92857142857142
# Anuual ROI over time:
# roi :113.57142857142857
# Anuual ROI over time:
# roi :113.21428571428571
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.5
# Anuual ROI over time:
# roi :112.14285714285714
# Anuual ROI over time:
# roi :111.78571428571429
# Anuual ROI over time:
# roi :185.35714285714286
# Anuual ROI over time:
# roi :185.0
# Anuual ROI over time:
# roi :184.64285714285717
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :183.92857142857142
# Anuual ROI over time:
# roi :183.57142857142856
# Anuual ROI over time:
# roi :183.2142857142857
# Anuual ROI over time:
# roi :42.857142857142854
# Anuual ROI over time:
# roi :42.5
# Anuual ROI over time:
# roi :42.142857142857146
# Anuual ROI over time:
# roi :41.785714285714285
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.07142857142857
# Anuual ROI over time:
# roi :40.714285714285715
# Anuual ROI over time:
# roi :114.28571428571428
# Anuual ROI over time:
# roi :113.92857142857142
# Anuual ROI over time:
# roi :113.57142857142857
# Anuual ROI over time:
# roi :113.21428571428571
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.5
# Anuual ROI over time:
# roi :112.14285714285714
# Anuual ROI over time:
# roi :185.71428571428572
# Anuual ROI over time:
# roi :185.35714285714286
# Anuual ROI over time:
# roi :185.0
# Anuual ROI over time:
# roi :184.64285714285717
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :183.92857142857142
# Anuual ROI over time:
# roi :183.57142857142856
# Anuual ROI over time:
# roi :149.0
# Anuual ROI over time:
# roi :148.5
# Anuual ROI over time:
# roi :148.0
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :147.0
# Anuual ROI over time:
# roi :146.5
# Anuual ROI over time:
# roi :146.0
# Anuual ROI over time:
# roi :274.0
# Anuual ROI over time:
# roi :273.5
# Anuual ROI over time:
# roi :273.0
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :272.0
# Anuual ROI over time:
# roi :271.5
# Anuual ROI over time:
# roi :271.0
# Anuual ROI over time:
# roi :399.0
# Anuual ROI over time:
# roi :398.5
# Anuual ROI over time:
# roi :398.0
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :397.0
# Anuual ROI over time:
# roi :396.5
# Anuual ROI over time:
# roi :396.0
# Anuual ROI over time:
# roi :149.5
# Anuual ROI over time:
# roi :149.0
# Anuual ROI over time:
# roi :148.5
# Anuual ROI over time:
# roi :148.0
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :147.0
# Anuual ROI over time:
# roi :146.5
# Anuual ROI over time:
# roi :274.5
# Anuual ROI over time:
# roi :274.0
# Anuual ROI over time:
# roi :273.5
# Anuual ROI over time:
# roi :273.0
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :272.0
# Anuual ROI over time:
# roi :271.5
# Anuual ROI over time:
# roi :399.5
# Anuual ROI over time:
# roi :399.0
# Anuual ROI over time:
# roi :398.5
# Anuual ROI over time:
# roi :398.0
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :397.0
# Anuual ROI over time:
# roi :396.5
# Anuual ROI over time:
# roi :150.0
# Anuual ROI over time:
# roi :149.5
# Anuual ROI over time:
# roi :149.0
# Anuual ROI over time:
# roi :148.5
# Anuual ROI over time:
# roi :148.0
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :147.0
# Anuual ROI over time:
# roi :275.0
# Anuual ROI over time:
# roi :274.5
# Anuual ROI over time:
# roi :274.0
# Anuual ROI over time:
# roi :273.5
# Anuual ROI over time:
# roi :273.0
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :272.0
# Anuual ROI over time:
# roi :400.0
# Anuual ROI over time:
# roi :399.5
# Anuual ROI over time:
# roi :399.0
# Anuual ROI over time:
# roi :398.5
# Anuual ROI over time:
# roi :398.0
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :397.0
# Anuual ROI over time:
# roi :99.2
# Anuual ROI over time:
# roi :98.8
# Anuual ROI over time:
# roi :98.4
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.6
# Anuual ROI over time:
# roi :97.2
# Anuual ROI over time:
# roi :96.8
# Anuual ROI over time:
# roi :199.2
# Anuual ROI over time:
# roi :198.8
# Anuual ROI over time:
# roi :198.4
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.6
# Anuual ROI over time:
# roi :197.2
# Anuual ROI over time:
# roi :196.8
# Anuual ROI over time:
# roi :299.2
# Anuual ROI over time:
# roi :298.8
# Anuual ROI over time:
# roi :298.4
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.6
# Anuual ROI over time:
# roi :297.2
# Anuual ROI over time:
# roi :296.8
# Anuual ROI over time:
# roi :99.6
# Anuual ROI over time:
# roi :99.2
# Anuual ROI over time:
# roi :98.8
# Anuual ROI over time:
# roi :98.4
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.6
# Anuual ROI over time:
# roi :97.2
# Anuual ROI over time:
# roi :199.6
# Anuual ROI over time:
# roi :199.2
# Anuual ROI over time:
# roi :198.8
# Anuual ROI over time:
# roi :198.4
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.6
# Anuual ROI over time:
# roi :197.2
# Anuual ROI over time:
# roi :299.6
# Anuual ROI over time:
# roi :299.2
# Anuual ROI over time:
# roi :298.8
# Anuual ROI over time:
# roi :298.4
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.6
# Anuual ROI over time:
# roi :297.2
# Anuual ROI over time:
# roi :100.0
# Anuual ROI over time:
# roi :99.6
# Anuual ROI over time:
# roi :99.2
# Anuual ROI over time:
# roi :98.8
# Anuual ROI over time:
# roi :98.4
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.6
# Anuual ROI over time:
# roi :200.0
# Anuual ROI over time:
# roi :199.6
# Anuual ROI over time:
# roi :199.2
# Anuual ROI over time:
# roi :198.8
# Anuual ROI over time:
# roi :198.4
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.6
# Anuual ROI over time:
# roi :300.0
# Anuual ROI over time:
# roi :299.6
# Anuual ROI over time:
# roi :299.2
# Anuual ROI over time:
# roi :298.8
# Anuual ROI over time:
# roi :298.4
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.6
# Anuual ROI over time:
# roi :66.0
# Anuual ROI over time:
# roi :65.66666666666666
# Anuual ROI over time:
# roi :65.33333333333333
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :64.66666666666666
# Anuual ROI over time:
# roi :64.33333333333333
# Anuual ROI over time:
# roi :64.0
# Anuual ROI over time:
# roi :149.33333333333334
# Anuual ROI over time:
# roi :149.0
# Anuual ROI over time:
# roi :148.66666666666666
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :148.0
# Anuual ROI over time:
# roi :147.66666666666666
# Anuual ROI over time:
# roi :147.33333333333334
# Anuual ROI over time:
# roi :232.66666666666666
# Anuual ROI over time:
# roi :232.33333333333331
# Anuual ROI over time:
# roi :231.99999999999997
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.33333333333334
# Anuual ROI over time:
# roi :231.0
# Anuual ROI over time:
# roi :230.66666666666666
# Anuual ROI over time:
# roi :66.33333333333333
# Anuual ROI over time:
# roi :66.0
# Anuual ROI over time:
# roi :65.66666666666666
# Anuual ROI over time:
# roi :65.33333333333333
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :64.66666666666666
# Anuual ROI over time:
# roi :64.33333333333333
# Anuual ROI over time:
# roi :149.66666666666666
# Anuual ROI over time:
# roi :149.33333333333334
# Anuual ROI over time:
# roi :149.0
# Anuual ROI over time:
# roi :148.66666666666666
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :148.0
# Anuual ROI over time:
# roi :147.66666666666666
# Anuual ROI over time:
# roi :233.0
# Anuual ROI over time:
# roi :232.66666666666666
# Anuual ROI over time:
# roi :232.33333333333331
# Anuual ROI over time:
# roi :231.99999999999997
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.33333333333334
# Anuual ROI over time:
# roi :231.0
# Anuual ROI over time:
# roi :66.66666666666666
# Anuual ROI over time:
# roi :66.33333333333333
# Anuual ROI over time:
# roi :66.0
# Anuual ROI over time:
# roi :65.66666666666666
# Anuual ROI over time:
# roi :65.33333333333333
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :64.66666666666666
# Anuual ROI over time:
# roi :150.0
# Anuual ROI over time:
# roi :149.66666666666666
# Anuual ROI over time:
# roi :149.33333333333334
# Anuual ROI over time:
# roi :149.0
# Anuual ROI over time:
# roi :148.66666666666666
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :148.0
# Anuual ROI over time:
# roi :233.33333333333334
# Anuual ROI over time:
# roi :233.0
# Anuual ROI over time:
# roi :232.66666666666666
# Anuual ROI over time:
# roi :232.33333333333331
# Anuual ROI over time:
# roi :231.99999999999997
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.33333333333334
# Anuual ROI over time:
# roi :42.285714285714285
# Anuual ROI over time:
# roi :42.0
# Anuual ROI over time:
# roi :41.714285714285715
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.14285714285714
# Anuual ROI over time:
# roi :40.85714285714286
# Anuual ROI over time:
# roi :40.57142857142857
# Anuual ROI over time:
# roi :113.71428571428572
# Anuual ROI over time:
# roi :113.42857142857143
# Anuual ROI over time:
# roi :113.14285714285714
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.57142857142857
# Anuual ROI over time:
# roi :112.28571428571428
# Anuual ROI over time:
# roi :112.00000000000001
# Anuual ROI over time:
# roi :185.14285714285714
# Anuual ROI over time:
# roi :184.85714285714286
# Anuual ROI over time:
# roi :184.57142857142856
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :184.0
# Anuual ROI over time:
# roi :183.71428571428572
# Anuual ROI over time:
# roi :183.42857142857142
# Anuual ROI over time:
# roi :42.57142857142857
# Anuual ROI over time:
# roi :42.285714285714285
# Anuual ROI over time:
# roi :42.0
# Anuual ROI over time:
# roi :41.714285714285715
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.14285714285714
# Anuual ROI over time:
# roi :40.85714285714286
# Anuual ROI over time:
# roi :113.99999999999999
# Anuual ROI over time:
# roi :113.71428571428572
# Anuual ROI over time:
# roi :113.42857142857143
# Anuual ROI over time:
# roi :113.14285714285714
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.57142857142857
# Anuual ROI over time:
# roi :112.28571428571428
# Anuual ROI over time:
# roi :185.42857142857144
# Anuual ROI over time:
# roi :185.14285714285714
# Anuual ROI over time:
# roi :184.85714285714286
# Anuual ROI over time:
# roi :184.57142857142856
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :184.0
# Anuual ROI over time:
# roi :183.71428571428572
# Anuual ROI over time:
# roi :42.857142857142854
# Anuual ROI over time:
# roi :42.57142857142857
# Anuual ROI over time:
# roi :42.285714285714285
# Anuual ROI over time:
# roi :42.0
# Anuual ROI over time:
# roi :41.714285714285715
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.14285714285714
# Anuual ROI over time:
# roi :114.28571428571428
# Anuual ROI over time:
# roi :113.99999999999999
# Anuual ROI over time:
# roi :113.71428571428572
# Anuual ROI over time:
# roi :113.42857142857143
# Anuual ROI over time:
# roi :113.14285714285714
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.57142857142857
# Anuual ROI over time:
# roi :185.71428571428572
# Anuual ROI over time:
# roi :185.42857142857144
# Anuual ROI over time:
# roi :185.14285714285714
# Anuual ROI over time:
# roi :184.85714285714286
# Anuual ROI over time:
# roi :184.57142857142856
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :184.0
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :147.91666666666669
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :147.08333333333334
# Anuual ROI over time:
# roi :146.66666666666666
# Anuual ROI over time:
# roi :274.1666666666667
# Anuual ROI over time:
# roi :273.75
# Anuual ROI over time:
# roi :273.3333333333333
# Anuual ROI over time:
# roi :272.91666666666663
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :272.0833333333333
# Anuual ROI over time:
# roi :271.6666666666667
# Anuual ROI over time:
# roi :399.1666666666667
# Anuual ROI over time:
# roi :398.75
# Anuual ROI over time:
# roi :398.3333333333333
# Anuual ROI over time:
# roi :397.91666666666663
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :397.0833333333333
# Anuual ROI over time:
# roi :396.6666666666667
# Anuual ROI over time:
# roi :149.58333333333334
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :147.91666666666669
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :147.08333333333334
# Anuual ROI over time:
# roi :274.5833333333333
# Anuual ROI over time:
# roi :274.1666666666667
# Anuual ROI over time:
# roi :273.75
# Anuual ROI over time:
# roi :273.3333333333333
# Anuual ROI over time:
# roi :272.91666666666663
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :272.0833333333333
# Anuual ROI over time:
# roi :399.5833333333333
# Anuual ROI over time:
# roi :399.1666666666667
# Anuual ROI over time:
# roi :398.75
# Anuual ROI over time:
# roi :398.3333333333333
# Anuual ROI over time:
# roi :397.91666666666663
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :397.0833333333333
# Anuual ROI over time:
# roi :150.0
# Anuual ROI over time:
# roi :149.58333333333334
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.75
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :147.91666666666669
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :275.0
# Anuual ROI over time:
# roi :274.5833333333333
# Anuual ROI over time:
# roi :274.1666666666667
# Anuual ROI over time:
# roi :273.75
# Anuual ROI over time:
# roi :273.3333333333333
# Anuual ROI over time:
# roi :272.91666666666663
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :400.0
# Anuual ROI over time:
# roi :399.5833333333333
# Anuual ROI over time:
# roi :399.1666666666667
# Anuual ROI over time:
# roi :398.75
# Anuual ROI over time:
# roi :398.3333333333333
# Anuual ROI over time:
# roi :397.91666666666663
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :99.33333333333333
# Anuual ROI over time:
# roi :99.0
# Anuual ROI over time:
# roi :98.66666666666667
# Anuual ROI over time:
# roi :98.33333333333333
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.66666666666667
# Anuual ROI over time:
# roi :97.33333333333334
# Anuual ROI over time:
# roi :199.33333333333334
# Anuual ROI over time:
# roi :199.0
# Anuual ROI over time:
# roi :198.66666666666666
# Anuual ROI over time:
# roi :198.33333333333334
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.66666666666666
# Anuual ROI over time:
# roi :197.33333333333334
# Anuual ROI over time:
# roi :299.3333333333333
# Anuual ROI over time:
# roi :299.0
# Anuual ROI over time:
# roi :298.6666666666667
# Anuual ROI over time:
# roi :298.3333333333333
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.66666666666663
# Anuual ROI over time:
# roi :297.3333333333333
# Anuual ROI over time:
# roi :99.66666666666667
# Anuual ROI over time:
# roi :99.33333333333333
# Anuual ROI over time:
# roi :99.0
# Anuual ROI over time:
# roi :98.66666666666667
# Anuual ROI over time:
# roi :98.33333333333333
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.66666666666667
# Anuual ROI over time:
# roi :199.66666666666666
# Anuual ROI over time:
# roi :199.33333333333334
# Anuual ROI over time:
# roi :199.0
# Anuual ROI over time:
# roi :198.66666666666666
# Anuual ROI over time:
# roi :198.33333333333334
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.66666666666666
# Anuual ROI over time:
# roi :299.6666666666667
# Anuual ROI over time:
# roi :299.3333333333333
# Anuual ROI over time:
# roi :299.0
# Anuual ROI over time:
# roi :298.6666666666667
# Anuual ROI over time:
# roi :298.3333333333333
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.66666666666663
# Anuual ROI over time:
# roi :100.0
# Anuual ROI over time:
# roi :99.66666666666667
# Anuual ROI over time:
# roi :99.33333333333333
# Anuual ROI over time:
# roi :99.0
# Anuual ROI over time:
# roi :98.66666666666667
# Anuual ROI over time:
# roi :98.33333333333333
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :200.0
# Anuual ROI over time:
# roi :199.66666666666666
# Anuual ROI over time:
# roi :199.33333333333334
# Anuual ROI over time:
# roi :199.0
# Anuual ROI over time:
# roi :198.66666666666666
# Anuual ROI over time:
# roi :198.33333333333334
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :300.0
# Anuual ROI over time:
# roi :299.6666666666667
# Anuual ROI over time:
# roi :299.3333333333333
# Anuual ROI over time:
# roi :299.0
# Anuual ROI over time:
# roi :298.6666666666667
# Anuual ROI over time:
# roi :298.3333333333333
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :66.11111111111111
# Anuual ROI over time:
# roi :65.83333333333333
# Anuual ROI over time:
# roi :65.55555555555556
# Anuual ROI over time:
# roi :65.27777777777779
# Anuual ROI over time:
# roi :65.0
# 100%|████████████████████████████████████████████████████████████████████████████| 1008/1008 [00:00<00:00, 2871.20it/s]
# Anuual ROI over time:
# roi :64.72222222222223
# Anuual ROI over time:
# roi :64.44444444444444
# Anuual ROI over time:
# roi :149.44444444444446
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.88888888888889
# Anuual ROI over time:
# roi :148.61111111111111
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :148.05555555555557
# Anuual ROI over time:
# roi :147.77777777777777
# Anuual ROI over time:
# roi :232.7777777777778
# Anuual ROI over time:
# roi :232.50000000000003
# Anuual ROI over time:
# roi :232.22222222222223
# Anuual ROI over time:
# roi :231.94444444444446
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.3888888888889
# Anuual ROI over time:
# roi :231.1111111111111
# Anuual ROI over time:
# roi :66.38888888888889
# Anuual ROI over time:
# roi :66.11111111111111
# Anuual ROI over time:
# roi :65.83333333333333
# Anuual ROI over time:
# roi :65.55555555555556
# Anuual ROI over time:
# roi :65.27777777777779
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :64.72222222222223
# Anuual ROI over time:
# roi :149.72222222222223
# Anuual ROI over time:
# roi :149.44444444444446
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.88888888888889
# Anuual ROI over time:
# roi :148.61111111111111
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :148.05555555555557
# Anuual ROI over time:
# roi :233.05555555555557
# Anuual ROI over time:
# roi :232.7777777777778
# Anuual ROI over time:
# roi :232.50000000000003
# Anuual ROI over time:
# roi :232.22222222222223
# Anuual ROI over time:
# roi :231.94444444444446
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.3888888888889
# Anuual ROI over time:
# roi :66.66666666666666
# Anuual ROI over time:
# roi :66.38888888888889
# Anuual ROI over time:
# roi :66.11111111111111
# Anuual ROI over time:
# roi :65.83333333333333
# Anuual ROI over time:
# roi :65.55555555555556
# Anuual ROI over time:
# roi :65.27777777777779
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :150.0
# Anuual ROI over time:
# roi :149.72222222222223
# Anuual ROI over time:
# roi :149.44444444444446
# Anuual ROI over time:
# roi :149.16666666666666
# Anuual ROI over time:
# roi :148.88888888888889
# Anuual ROI over time:
# roi :148.61111111111111
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :233.33333333333334
# Anuual ROI over time:
# roi :233.05555555555557
# Anuual ROI over time:
# roi :232.7777777777778
# Anuual ROI over time:
# roi :232.50000000000003
# Anuual ROI over time:
# roi :232.22222222222223
# Anuual ROI over time:
# roi :231.94444444444446
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :42.38095238095238
# Anuual ROI over time:
# roi :42.142857142857146
# Anuual ROI over time:
# roi :41.904761904761905
# Anuual ROI over time:
# roi :41.66666666666667
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.19047619047619
# Anuual ROI over time:
# roi :40.95238095238095
# Anuual ROI over time:
# roi :113.80952380952381
# Anuual ROI over time:
# roi :113.57142857142857
# Anuual ROI over time:
# roi :113.33333333333333
# Anuual ROI over time:
# roi :113.09523809523809
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.61904761904762
# Anuual ROI over time:
# roi :112.38095238095238
# Anuual ROI over time:
# roi :185.23809523809524
# Anuual ROI over time:
# roi :185.0
# Anuual ROI over time:
# roi :184.76190476190476
# Anuual ROI over time:
# roi :184.52380952380955
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :184.04761904761904
# Anuual ROI over time:
# roi :183.8095238095238
# Anuual ROI over time:
# roi :42.61904761904762
# Anuual ROI over time:
# roi :42.38095238095238
# Anuual ROI over time:
# roi :42.142857142857146
# Anuual ROI over time:
# roi :41.904761904761905
# Anuual ROI over time:
# roi :41.66666666666667
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.19047619047619
# Anuual ROI over time:
# roi :114.04761904761904
# Anuual ROI over time:
# roi :113.80952380952381
# Anuual ROI over time:
# roi :113.57142857142857
# Anuual ROI over time:
# roi :113.33333333333333
# Anuual ROI over time:
# roi :113.09523809523809
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.61904761904762
# Anuual ROI over time:
# roi :185.47619047619048
# Anuual ROI over time:
# roi :185.23809523809524
# Anuual ROI over time:
# roi :185.0
# Anuual ROI over time:
# roi :184.76190476190476
# Anuual ROI over time:
# roi :184.52380952380955
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :184.04761904761904
# Anuual ROI over time:
# roi :42.857142857142854
# Anuual ROI over time:
# roi :42.61904761904762
# Anuual ROI over time:
# roi :42.38095238095238
# Anuual ROI over time:
# roi :42.142857142857146
# Anuual ROI over time:
# roi :41.904761904761905
# Anuual ROI over time:
# roi :41.66666666666667
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :114.28571428571428
# Anuual ROI over time:
# roi :114.04761904761904
# Anuual ROI over time:
# roi :113.80952380952381
# Anuual ROI over time:
# roi :113.57142857142857
# Anuual ROI over time:
# roi :113.33333333333333
# Anuual ROI over time:
# roi :113.09523809523809
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :185.71428571428572
# Anuual ROI over time:
# roi :185.47619047619048
# Anuual ROI over time:
# roi :185.23809523809524
# Anuual ROI over time:
# roi :185.0
# Anuual ROI over time:
# roi :184.76190476190476
# Anuual ROI over time:
# roi :184.52380952380955
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :149.28571428571428
# Anuual ROI over time:
# roi :148.92857142857144
# Anuual ROI over time:
# roi :148.57142857142858
# Anuual ROI over time:
# roi :148.21428571428572
# Anuual ROI over time:
# roi :147.85714285714286
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :147.14285714285717
# Anuual ROI over time:
# roi :274.2857142857143
# Anuual ROI over time:
# roi :273.92857142857144
# Anuual ROI over time:
# roi :273.57142857142856
# Anuual ROI over time:
# roi :273.2142857142857
# Anuual ROI over time:
# roi :272.8571428571429
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :272.14285714285717
# Anuual ROI over time:
# roi :399.2857142857143
# Anuual ROI over time:
# roi :398.92857142857144
# Anuual ROI over time:
# roi :398.57142857142856
# Anuual ROI over time:
# roi :398.2142857142857
# Anuual ROI over time:
# roi :397.8571428571429
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :397.14285714285717
# Anuual ROI over time:
# roi :149.64285714285714
# Anuual ROI over time:
# roi :149.28571428571428
# Anuual ROI over time:
# roi :148.92857142857144
# Anuual ROI over time:
# roi :148.57142857142858
# Anuual ROI over time:
# roi :148.21428571428572
# Anuual ROI over time:
# roi :147.85714285714286
# Anuual ROI over time:
# roi :147.5
# Anuual ROI over time:
# roi :274.64285714285717
# Anuual ROI over time:
# roi :274.2857142857143
# Anuual ROI over time:
# roi :273.92857142857144
# Anuual ROI over time:
# roi :273.57142857142856
# Anuual ROI over time:
# roi :273.2142857142857
# Anuual ROI over time:
# roi :272.8571428571429
# Anuual ROI over time:
# roi :272.5
# Anuual ROI over time:
# roi :399.64285714285717
# Anuual ROI over time:
# roi :399.2857142857143
# Anuual ROI over time:
# roi :398.92857142857144
# Anuual ROI over time:
# roi :398.57142857142856
# Anuual ROI over time:
# roi :398.2142857142857
# Anuual ROI over time:
# roi :397.8571428571429
# Anuual ROI over time:
# roi :397.5
# Anuual ROI over time:
# roi :150.0
# Anuual ROI over time:
# roi :149.64285714285714
# Anuual ROI over time:
# roi :149.28571428571428
# Anuual ROI over time:
# roi :148.92857142857144
# Anuual ROI over time:
# roi :148.57142857142858
# Anuual ROI over time:
# roi :148.21428571428572
# Anuual ROI over time:
# roi :147.85714285714286
# Anuual ROI over time:
# roi :275.0
# Anuual ROI over time:
# roi :274.64285714285717
# Anuual ROI over time:
# roi :274.2857142857143
# Anuual ROI over time:
# roi :273.92857142857144
# Anuual ROI over time:
# roi :273.57142857142856
# Anuual ROI over time:
# roi :273.2142857142857
# Anuual ROI over time:
# roi :272.8571428571429
# Anuual ROI over time:
# roi :400.0
# Anuual ROI over time:
# roi :399.64285714285717
# Anuual ROI over time:
# roi :399.2857142857143
# Anuual ROI over time:
# roi :398.92857142857144
# Anuual ROI over time:
# roi :398.57142857142856
# Anuual ROI over time:
# roi :398.2142857142857
# Anuual ROI over time:
# roi :397.8571428571429
# Anuual ROI over time:
# roi :99.42857142857143
# Anuual ROI over time:
# roi :99.14285714285714
# Anuual ROI over time:
# roi :98.85714285714286
# Anuual ROI over time:
# roi :98.57142857142858
# Anuual ROI over time:
# roi :98.28571428571429
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :97.71428571428571
# Anuual ROI over time:
# roi :199.42857142857142
# Anuual ROI over time:
# roi :199.14285714285714
# Anuual ROI over time:
# roi :198.85714285714286
# Anuual ROI over time:
# roi :198.57142857142858
# Anuual ROI over time:
# roi :198.28571428571428
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :197.71428571428572
# Anuual ROI over time:
# roi :299.42857142857144
# Anuual ROI over time:
# roi :299.14285714285717
# Anuual ROI over time:
# roi :298.85714285714283
# Anuual ROI over time:
# roi :298.57142857142856
# Anuual ROI over time:
# roi :298.2857142857143
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :297.7142857142857
# Anuual ROI over time:
# roi :99.71428571428571
# Anuual ROI over time:
# roi :99.42857142857143
# Anuual ROI over time:
# roi :99.14285714285714
# Anuual ROI over time:
# roi :98.85714285714286
# Anuual ROI over time:
# roi :98.57142857142858
# Anuual ROI over time:
# roi :98.28571428571429
# Anuual ROI over time:
# roi :98.0
# Anuual ROI over time:
# roi :199.71428571428572
# Anuual ROI over time:
# roi :199.42857142857142
# Anuual ROI over time:
# roi :199.14285714285714
# Anuual ROI over time:
# roi :198.85714285714286
# Anuual ROI over time:
# roi :198.57142857142858
# Anuual ROI over time:
# roi :198.28571428571428
# Anuual ROI over time:
# roi :198.0
# Anuual ROI over time:
# roi :299.7142857142857
# Anuual ROI over time:
# roi :299.42857142857144
# Anuual ROI over time:
# roi :299.14285714285717
# Anuual ROI over time:
# roi :298.85714285714283
# Anuual ROI over time:
# roi :298.57142857142856
# Anuual ROI over time:
# roi :298.2857142857143
# Anuual ROI over time:
# roi :298.0
# Anuual ROI over time:
# roi :100.0
# Anuual ROI over time:
# roi :99.71428571428571
# Anuual ROI over time:
# roi :99.42857142857143
# Anuual ROI over time:
# roi :99.14285714285714
# Anuual ROI over time:
# roi :98.85714285714286
# Anuual ROI over time:
# roi :98.57142857142858
# Anuual ROI over time:
# roi :98.28571428571429
# Anuual ROI over time:
# roi :200.0
# Anuual ROI over time:
# roi :199.71428571428572
# Anuual ROI over time:
# roi :199.42857142857142
# Anuual ROI over time:
# roi :199.14285714285714
# Anuual ROI over time:
# roi :198.85714285714286
# Anuual ROI over time:
# roi :198.57142857142858
# Anuual ROI over time:
# roi :198.28571428571428
# Anuual ROI over time:
# roi :300.0
# Anuual ROI over time:
# roi :299.7142857142857
# Anuual ROI over time:
# roi :299.42857142857144
# Anuual ROI over time:
# roi :299.14285714285717
# Anuual ROI over time:
# roi :298.85714285714283
# Anuual ROI over time:
# roi :298.57142857142856
# Anuual ROI over time:
# roi :298.2857142857143
# Anuual ROI over time:
# roi :66.19047619047619
# Anuual ROI over time:
# roi :65.95238095238095
# Anuual ROI over time:
# roi :65.71428571428571
# Anuual ROI over time:
# roi :65.47619047619048
# Anuual ROI over time:
# roi :65.23809523809524
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :64.76190476190476
# Anuual ROI over time:
# roi :149.52380952380952
# Anuual ROI over time:
# roi :149.28571428571428
# Anuual ROI over time:
# roi :149.04761904761904
# Anuual ROI over time:
# roi :148.80952380952382
# Anuual ROI over time:
# roi :148.57142857142858
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :148.0952380952381
# Anuual ROI over time:
# roi :232.85714285714286
# Anuual ROI over time:
# roi :232.61904761904765
# Anuual ROI over time:
# roi :232.3809523809524
# Anuual ROI over time:
# roi :232.14285714285717
# Anuual ROI over time:
# roi :231.90476190476193
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :231.42857142857144
# Anuual ROI over time:
# roi :66.42857142857143
# Anuual ROI over time:
# roi :66.19047619047619
# Anuual ROI over time:
# roi :65.95238095238095
# Anuual ROI over time:
# roi :65.71428571428571
# Anuual ROI over time:
# roi :65.47619047619048
# Anuual ROI over time:
# roi :65.23809523809524
# Anuual ROI over time:
# roi :65.0
# Anuual ROI over time:
# roi :149.76190476190476
# Anuual ROI over time:
# roi :149.52380952380952
# Anuual ROI over time:
# roi :149.28571428571428
# Anuual ROI over time:
# roi :149.04761904761904
# Anuual ROI over time:
# roi :148.80952380952382
# Anuual ROI over time:
# roi :148.57142857142858
# Anuual ROI over time:
# roi :148.33333333333334
# Anuual ROI over time:
# roi :233.0952380952381
# Anuual ROI over time:
# roi :232.85714285714286
# Anuual ROI over time:
# roi :232.61904761904765
# Anuual ROI over time:
# roi :232.3809523809524
# Anuual ROI over time:
# roi :232.14285714285717
# Anuual ROI over time:
# roi :231.90476190476193
# Anuual ROI over time:
# roi :231.66666666666669
# Anuual ROI over time:
# roi :66.66666666666666
# Anuual ROI over time:
# roi :66.42857142857143
# Anuual ROI over time:
# roi :66.19047619047619
# Anuual ROI over time:
# roi :65.95238095238095
# Anuual ROI over time:
# roi :65.71428571428571
# Anuual ROI over time:
# roi :65.47619047619048
# Anuual ROI over time:
# roi :65.23809523809524
# Anuual ROI over time:
# roi :150.0
# Anuual ROI over time:
# roi :149.76190476190476
# Anuual ROI over time:
# roi :149.52380952380952
# Anuual ROI over time:
# roi :149.28571428571428
# Anuual ROI over time:
# roi :149.04761904761904
# Anuual ROI over time:
# roi :148.80952380952382
# Anuual ROI over time:
# roi :148.57142857142858
# Anuual ROI over time:
# roi :233.33333333333334
# Anuual ROI over time:
# roi :233.0952380952381
# Anuual ROI over time:
# roi :232.85714285714286
# Anuual ROI over time:
# roi :232.61904761904765
# Anuual ROI over time:
# roi :232.3809523809524
# Anuual ROI over time:
# roi :232.14285714285717
# Anuual ROI over time:
# roi :231.90476190476193
# Anuual ROI over time:
# roi :42.44897959183673
# Anuual ROI over time:
# roi :42.244897959183675
# Anuual ROI over time:
# roi :42.04081632653061
# Anuual ROI over time:
# roi :41.83673469387755
# Anuual ROI over time:
# roi :41.63265306122449
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :41.224489795918366
# Anuual ROI over time:
# roi :113.87755102040818
# Anuual ROI over time:
# roi :113.6734693877551
# Anuual ROI over time:
# roi :113.46938775510205
# Anuual ROI over time:
# roi :113.26530612244898
# Anuual ROI over time:
# roi :113.06122448979592
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :112.65306122448979
# Anuual ROI over time:
# roi :185.30612244897958
# Anuual ROI over time:
# roi :185.10204081632654
# Anuual ROI over time:
# roi :184.89795918367346
# Anuual ROI over time:
# roi :184.6938775510204
# Anuual ROI over time:
# roi :184.48979591836735
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :184.08163265306123
# Anuual ROI over time:
# roi :42.6530612244898
# Anuual ROI over time:
# roi :42.44897959183673
# Anuual ROI over time:
# roi :42.244897959183675
# Anuual ROI over time:
# roi :42.04081632653061
# Anuual ROI over time:
# roi :41.83673469387755
# Anuual ROI over time:
# roi :41.63265306122449
# Anuual ROI over time:
# roi :41.42857142857143
# Anuual ROI over time:
# roi :114.08163265306122
# Anuual ROI over time:
# roi :113.87755102040818
# Anuual ROI over time:
# roi :113.6734693877551
# Anuual ROI over time:
# roi :113.46938775510205
# Anuual ROI over time:
# roi :113.26530612244898
# Anuual ROI over time:
# roi :113.06122448979592
# Anuual ROI over time:
# roi :112.85714285714286
# Anuual ROI over time:
# roi :185.51020408163265
# Anuual ROI over time:
# roi :185.30612244897958
# Anuual ROI over time:
# roi :185.10204081632654
# Anuual ROI over time:
# roi :184.89795918367346
# Anuual ROI over time:
# roi :184.6938775510204
# Anuual ROI over time:
# roi :184.48979591836735
# Anuual ROI over time:
# roi :184.28571428571428
# Anuual ROI over time:
# roi :42.857142857142854
# Anuual ROI over time:
# roi :42.6530612244898
# Anuual ROI over time:
# roi :42.44897959183673
# Anuual ROI over time:
# roi :42.244897959183675
# Anuual ROI over time:
# roi :42.04081632653061
# Anuual ROI over time:
# roi :41.83673469387755
# Anuual ROI over time:
# roi :41.63265306122449
# Anuual ROI over time:
# roi :114.28571428571428
# Anuual ROI over time:
# roi :114.08163265306122
# Anuual ROI over time:
# roi :113.87755102040818
# Anuual ROI over time:
# roi :113.6734693877551
# Anuual ROI over time:
# roi :113.46938775510205
# Anuual ROI over time:
# roi :113.26530612244898
# Anuual ROI over time:
# roi :113.06122448979592
# Anuual ROI over time:
# roi :185.71428571428572
# Anuual ROI over time:
# roi :185.51020408163265
# Anuual ROI over time:
# roi :185.30612244897958
# Anuual ROI over time:
# roi :185.10204081632654
# Anuual ROI over time:
# roi :184.89795918367346
# Anuual ROI over time:
# roi :184.6938775510204
# Anuual ROI over time:
# roi :184.48979591836735

# %%
# Create a DataFrame.
sa.df
# Out:
#       share_no  buying_price  dividend  selling_price  costs  Annual ROI
# 0          400            40       100            100    300      148.75
# 1          400            40       100            100    400     148.125
# 2          400            40       100            100    500       147.5
# 3          400            40       100            100    600     146.875
# 4          400            40       100            100    700      146.25
# ...        ...           ...       ...            ...    ...         ...
# 1003       700            70       300            200    500  185.306122
# 1004       700            70       300            200    600  185.102041
# 1005       700            70       300            200    700  184.897959
# 1006       700            70       300            200    800  184.693878
# 1007       700            70       300            200    900  184.489796
#
# [1008 rows x 6 columns]

# %%
# Create a visualisation.
sa.plot()

# %%
# Display results as a DataFrame.
sa.styled_dfs()
# Out:
# <h2>Annual ROI by share_no vs. buying_price</h2>
# <style type="text/css">
# #T_ee99a_row0_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_ee99a_row0_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_ee99a_row0_col2 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_ee99a_row0_col3, #T_ee99a_row1_col3, #T_ee99a_row2_col3, #T_ee99a_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ee99a_row1_col0, #T_ee99a_row2_col0, #T_ee99a_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ee99a_row1_col1, #T_ee99a_row2_col1, #T_ee99a_row3_col1 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_ee99a_row1_col2, #T_ee99a_row2_col2, #T_ee99a_row3_col2 {
#   background-color: #75c465;
#   color: #000000;
# }
# </style>
# <table id="T_ee99a">
#   <caption>Annual ROI - share_no vs. buying_price</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee99a_level0_col0" class="col_heading level0 col0" >40</th>
#       <th id="T_ee99a_level0_col1" class="col_heading level0 col1" >50</th>
#       <th id="T_ee99a_level0_col2" class="col_heading level0 col2" >60</th>
#       <th id="T_ee99a_level0_col3" class="col_heading level0 col3" >70</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >share_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee99a_level0_row0" class="row_heading level0 row0" >400</th>
#       <td id="T_ee99a_row0_col0" class="data row0 col0" >272.500000</td>
#       <td id="T_ee99a_row0_col1" class="data row0 col1" >198.000000</td>
#       <td id="T_ee99a_row0_col2" class="data row0 col2" >148.333333</td>
#       <td id="T_ee99a_row0_col3" class="data row0 col3" >112.857143</td>
#     </tr>
#     <tr>
#       <th id="T_ee99a_level0_row1" class="row_heading level0 row1" >500</th>
#       <td id="T_ee99a_row1_col0" class="data row1 col0" >273.000000</td>
#       <td id="T_ee99a_row1_col1" class="data row1 col1" >198.400000</td>
#       <td id="T_ee99a_row1_col2" class="data row1 col2" >148.666667</td>
#       <td id="T_ee99a_row1_col3" class="data row1 col3" >113.142857</td>
#     </tr>
#     <tr>
#       <th id="T_ee99a_level0_row2" class="row_heading level0 row2" >600</th>
#       <td id="T_ee99a_row2_col0" class="data row2 col0" >273.333333</td>
#       <td id="T_ee99a_row2_col1" class="data row2 col1" >198.666667</td>
#       <td id="T_ee99a_row2_col2" class="data row2 col2" >148.888889</td>
#       <td id="T_ee99a_row2_col3" class="data row2 col3" >113.333333</td>
#     </tr>
#     <tr>
#       <th id="T_ee99a_level0_row3" class="row_heading level0 row3" >700</th>
#       <td id="T_ee99a_row3_col0" class="data row3 col0" >273.571429</td>
#       <td id="T_ee99a_row3_col1" class="data row3 col1" >198.857143</td>
#       <td id="T_ee99a_row3_col2" class="data row3 col2" >149.047619</td>
#       <td id="T_ee99a_row3_col3" class="data row3 col3" >113.469388</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by share_no vs. dividend</h2>
# <style type="text/css">
# #T_6f3db_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6f3db_row0_col1, #T_6f3db_row1_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_6f3db_row0_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_6f3db_row1_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_6f3db_row1_col2 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_6f3db_row2_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_6f3db_row2_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_6f3db_row2_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_6f3db_row3_col0 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_6f3db_row3_col1 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_6f3db_row3_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f3db">
#   <caption>Annual ROI - share_no vs. dividend</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f3db_level0_col0" class="col_heading level0 col0" >100</th>
#       <th id="T_6f3db_level0_col1" class="col_heading level0 col1" >200</th>
#       <th id="T_6f3db_level0_col2" class="col_heading level0 col2" >300</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >share_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f3db_level0_row0" class="row_heading level0 row0" >400</th>
#       <td id="T_6f3db_row0_col0" class="data row0 col0" >182.447917</td>
#       <td id="T_6f3db_row0_col1" class="data row0 col1" >182.922619</td>
#       <td id="T_6f3db_row0_col2" class="data row0 col2" >183.397321</td>
#     </tr>
#     <tr>
#       <th id="T_6f3db_level0_row1" class="row_heading level0 row1" >500</th>
#       <td id="T_6f3db_row1_col0" class="data row1 col0" >182.922619</td>
#       <td id="T_6f3db_row1_col1" class="data row1 col1" >183.302381</td>
#       <td id="T_6f3db_row1_col2" class="data row1 col2" >183.682143</td>
#     </tr>
#     <tr>
#       <th id="T_6f3db_level0_row2" class="row_heading level0 row2" >600</th>
#       <td id="T_6f3db_row2_col0" class="data row2 col0" >183.239087</td>
#       <td id="T_6f3db_row2_col1" class="data row2 col1" >183.555556</td>
#       <td id="T_6f3db_row2_col2" class="data row2 col2" >183.872024</td>
#     </tr>
#     <tr>
#       <th id="T_6f3db_level0_row3" class="row_heading level0 row3" >700</th>
#       <td id="T_6f3db_row3_col0" class="data row3 col0" >183.465136</td>
#       <td id="T_6f3db_row3_col1" class="data row3 col1" >183.736395</td>
#       <td id="T_6f3db_row3_col2" class="data row3 col2" >184.007653</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by share_no vs. selling_price</h2>
# <style type="text/css">
# #T_bf4ea_row0_col0, #T_bf4ea_row1_col0, #T_bf4ea_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bf4ea_row0_col1, #T_bf4ea_row1_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_bf4ea_row0_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_bf4ea_row1_col2, #T_bf4ea_row2_col2, #T_bf4ea_row3_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_bf4ea_row2_col1, #T_bf4ea_row3_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_bf4ea_row3_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bf4ea">
#   <caption>Annual ROI - share_no vs. selling_price</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf4ea_level0_col0" class="col_heading level0 col0" >100</th>
#       <th id="T_bf4ea_level0_col1" class="col_heading level0 col1" >150</th>
#       <th id="T_bf4ea_level0_col2" class="col_heading level0 col2" >200</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >share_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf4ea_level0_row0" class="row_heading level0 row0" >400</th>
#       <td id="T_bf4ea_row0_col0" class="data row0 col0" >87.982143</td>
#       <td id="T_bf4ea_row0_col1" class="data row0 col1" >182.922619</td>
#       <td id="T_bf4ea_row0_col2" class="data row0 col2" >277.863095</td>
#     </tr>
#     <tr>
#       <th id="T_bf4ea_level0_row1" class="row_heading level0 row1" >500</th>
#       <td id="T_bf4ea_row1_col0" class="data row1 col0" >88.361905</td>
#       <td id="T_bf4ea_row1_col1" class="data row1 col1" >183.302381</td>
#       <td id="T_bf4ea_row1_col2" class="data row1 col2" >278.242857</td>
#     </tr>
#     <tr>
#       <th id="T_bf4ea_level0_row2" class="row_heading level0 row2" >600</th>
#       <td id="T_bf4ea_row2_col0" class="data row2 col0" >88.615079</td>
#       <td id="T_bf4ea_row2_col1" class="data row2 col1" >183.555556</td>
#       <td id="T_bf4ea_row2_col2" class="data row2 col2" >278.496032</td>
#     </tr>
#     <tr>
#       <th id="T_bf4ea_level0_row3" class="row_heading level0 row3" >700</th>
#       <td id="T_bf4ea_row3_col0" class="data row3 col0" >88.795918</td>
#       <td id="T_bf4ea_row3_col1" class="data row3 col1" >183.736395</td>
#       <td id="T_bf4ea_row3_col2" class="data row3 col2" >278.676871</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by share_no vs. costs</h2>
# <style type="text/css">
# #T_e9453_row0_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_e9453_row0_col1, #T_e9453_row2_col2 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_e9453_row0_col2 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_e9453_row0_col3, #T_e9453_row1_col4, #T_e9453_row2_col5, #T_e9453_row3_col6 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_e9453_row0_col4 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_e9453_row0_col5 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_e9453_row0_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e9453_row1_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_e9453_row1_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_e9453_row1_col2 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_e9453_row1_col3 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_e9453_row1_col5 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_e9453_row1_col6 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_e9453_row2_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_e9453_row2_col1 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_e9453_row2_col3 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_e9453_row2_col4 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_e9453_row2_col6 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_e9453_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e9453_row3_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_e9453_row3_col2 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_e9453_row3_col3 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_e9453_row3_col4 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_e9453_row3_col5 {
#   background-color: #feeda1;
#   color: #000000;
# }
# </style>
# <table id="T_e9453">
#   <caption>Annual ROI - share_no vs. costs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9453_level0_col0" class="col_heading level0 col0" >300</th>
#       <th id="T_e9453_level0_col1" class="col_heading level0 col1" >400</th>
#       <th id="T_e9453_level0_col2" class="col_heading level0 col2" >500</th>
#       <th id="T_e9453_level0_col3" class="col_heading level0 col3" >600</th>
#       <th id="T_e9453_level0_col4" class="col_heading level0 col4" >700</th>
#       <th id="T_e9453_level0_col5" class="col_heading level0 col5" >800</th>
#       <th id="T_e9453_level0_col6" class="col_heading level0 col6" >900</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >share_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9453_level0_row0" class="row_heading level0 row0" >400</th>
#       <td id="T_e9453_row0_col0" class="data row0 col0" >184.346726</td>
#       <td id="T_e9453_row0_col1" class="data row0 col1" >183.872024</td>
#       <td id="T_e9453_row0_col2" class="data row0 col2" >183.397321</td>
#       <td id="T_e9453_row0_col3" class="data row0 col3" >182.922619</td>
#       <td id="T_e9453_row0_col4" class="data row0 col4" >182.447917</td>
#       <td id="T_e9453_row0_col5" class="data row0 col5" >181.973214</td>
#       <td id="T_e9453_row0_col6" class="data row0 col6" >181.498512</td>
#     </tr>
#     <tr>
#       <th id="T_e9453_level0_row1" class="row_heading level0 row1" >500</th>
#       <td id="T_e9453_row1_col0" class="data row1 col0" >184.441667</td>
#       <td id="T_e9453_row1_col1" class="data row1 col1" >184.061905</td>
#       <td id="T_e9453_row1_col2" class="data row1 col2" >183.682143</td>
#       <td id="T_e9453_row1_col3" class="data row1 col3" >183.302381</td>
#       <td id="T_e9453_row1_col4" class="data row1 col4" >182.922619</td>
#       <td id="T_e9453_row1_col5" class="data row1 col5" >182.542857</td>
#       <td id="T_e9453_row1_col6" class="data row1 col6" >182.163095</td>
#     </tr>
#     <tr>
#       <th id="T_e9453_level0_row2" class="row_heading level0 row2" >600</th>
#       <td id="T_e9453_row2_col0" class="data row2 col0" >184.504960</td>
#       <td id="T_e9453_row2_col1" class="data row2 col1" >184.188492</td>
#       <td id="T_e9453_row2_col2" class="data row2 col2" >183.872024</td>
#       <td id="T_e9453_row2_col3" class="data row2 col3" >183.555556</td>
#       <td id="T_e9453_row2_col4" class="data row2 col4" >183.239087</td>
#       <td id="T_e9453_row2_col5" class="data row2 col5" >182.922619</td>
#       <td id="T_e9453_row2_col6" class="data row2 col6" >182.606151</td>
#     </tr>
#     <tr>
#       <th id="T_e9453_level0_row3" class="row_heading level0 row3" >700</th>
#       <td id="T_e9453_row3_col0" class="data row3 col0" >184.550170</td>
#       <td id="T_e9453_row3_col1" class="data row3 col1" >184.278912</td>
#       <td id="T_e9453_row3_col2" class="data row3 col2" >184.007653</td>
#       <td id="T_e9453_row3_col3" class="data row3 col3" >183.736395</td>
#       <td id="T_e9453_row3_col4" class="data row3 col4" >183.465136</td>
#       <td id="T_e9453_row3_col5" class="data row3 col5" >183.193878</td>
#       <td id="T_e9453_row3_col6" class="data row3 col6" >182.922619</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by buying_price vs. dividend</h2>
# <style type="text/css">
# #T_c4d33_row0_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_c4d33_row0_col1, #T_c4d33_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c4d33_row1_col0 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_c4d33_row1_col1, #T_c4d33_row1_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_c4d33_row2_col0 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_c4d33_row2_col1, #T_c4d33_row2_col2 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_c4d33_row3_col0, #T_c4d33_row3_col1, #T_c4d33_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c4d33">
#   <caption>Annual ROI - buying_price vs. dividend</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4d33_level0_col0" class="col_heading level0 col0" >100</th>
#       <th id="T_c4d33_level0_col1" class="col_heading level0 col1" >200</th>
#       <th id="T_c4d33_level0_col2" class="col_heading level0 col2" >300</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >buying_price</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4d33_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_c4d33_row0_col0" class="data row0 col0" >272.626488</td>
#       <td id="T_c4d33_row0_col1" class="data row0 col1" >273.101190</td>
#       <td id="T_c4d33_row0_col2" class="data row0 col2" >273.575893</td>
#     </tr>
#     <tr>
#       <th id="T_c4d33_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_c4d33_row1_col0" class="data row1 col0" >198.101190</td>
#       <td id="T_c4d33_row1_col1" class="data row1 col1" >198.480952</td>
#       <td id="T_c4d33_row1_col2" class="data row1 col2" >198.860714</td>
#     </tr>
#     <tr>
#       <th id="T_c4d33_level0_row2" class="row_heading level0 row2" >60</th>
#       <td id="T_c4d33_row2_col0" class="data row2 col0" >148.417659</td>
#       <td id="T_c4d33_row2_col1" class="data row2 col1" >148.734127</td>
#       <td id="T_c4d33_row2_col2" class="data row2 col2" >149.050595</td>
#     </tr>
#     <tr>
#       <th id="T_c4d33_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_c4d33_row3_col0" class="data row3 col0" >112.929422</td>
#       <td id="T_c4d33_row3_col1" class="data row3 col1" >113.200680</td>
#       <td id="T_c4d33_row3_col2" class="data row3 col2" >113.471939</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by buying_price vs. selling_price</h2>
# <style type="text/css">
# #T_349ec_row0_col0, #T_349ec_row2_col1 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_349ec_row0_col1 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_349ec_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_349ec_row1_col0 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_349ec_row1_col1 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_349ec_row1_col2 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_349ec_row2_col0 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_349ec_row2_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_349ec_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_349ec_row3_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_349ec_row3_col2 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# </style>
# <table id="T_349ec">
#   <caption>Annual ROI - buying_price vs. selling_price</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_349ec_level0_col0" class="col_heading level0 col0" >100</th>
#       <th id="T_349ec_level0_col1" class="col_heading level0 col1" >150</th>
#       <th id="T_349ec_level0_col2" class="col_heading level0 col2" >200</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >buying_price</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_349ec_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_349ec_row0_col0" class="data row0 col0" >148.101190</td>
#       <td id="T_349ec_row0_col1" class="data row0 col1" >273.101190</td>
#       <td id="T_349ec_row0_col2" class="data row0 col2" >398.101190</td>
#     </tr>
#     <tr>
#       <th id="T_349ec_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_349ec_row1_col0" class="data row1 col0" >98.480952</td>
#       <td id="T_349ec_row1_col1" class="data row1 col1" >198.480952</td>
#       <td id="T_349ec_row1_col2" class="data row1 col2" >298.480952</td>
#     </tr>
#     <tr>
#       <th id="T_349ec_level0_row2" class="row_heading level0 row2" >60</th>
#       <td id="T_349ec_row2_col0" class="data row2 col0" >65.400794</td>
#       <td id="T_349ec_row2_col1" class="data row2 col1" >148.734127</td>
#       <td id="T_349ec_row2_col2" class="data row2 col2" >232.067460</td>
#     </tr>
#     <tr>
#       <th id="T_349ec_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_349ec_row3_col0" class="data row3 col0" >41.772109</td>
#       <td id="T_349ec_row3_col1" class="data row3 col1" >113.200680</td>
#       <td id="T_349ec_row3_col2" class="data row3 col2" >184.629252</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by buying_price vs. costs</h2>
# <style type="text/css">
# #T_58703_row0_col0, #T_58703_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_58703_row0_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_58703_row0_col3, #T_58703_row0_col4 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_58703_row0_col5 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_58703_row0_col6 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_58703_row1_col0, #T_58703_row1_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_58703_row1_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_58703_row1_col3, #T_58703_row1_col4 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_58703_row1_col5, #T_58703_row1_col6 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_58703_row2_col0, #T_58703_row2_col1 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_58703_row2_col2, #T_58703_row2_col3 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_58703_row2_col4, #T_58703_row2_col5 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_58703_row2_col6 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_58703_row3_col0, #T_58703_row3_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_58703_row3_col2, #T_58703_row3_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_58703_row3_col4, #T_58703_row3_col5, #T_58703_row3_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_58703">
#   <caption>Annual ROI - buying_price vs. costs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58703_level0_col0" class="col_heading level0 col0" >300</th>
#       <th id="T_58703_level0_col1" class="col_heading level0 col1" >400</th>
#       <th id="T_58703_level0_col2" class="col_heading level0 col2" >500</th>
#       <th id="T_58703_level0_col3" class="col_heading level0 col3" >600</th>
#       <th id="T_58703_level0_col4" class="col_heading level0 col4" >700</th>
#       <th id="T_58703_level0_col5" class="col_heading level0 col5" >800</th>
#       <th id="T_58703_level0_col6" class="col_heading level0 col6" >900</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >buying_price</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58703_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_58703_row0_col0" class="data row0 col0" >274.525298</td>
#       <td id="T_58703_row0_col1" class="data row0 col1" >274.050595</td>
#       <td id="T_58703_row0_col2" class="data row0 col2" >273.575893</td>
#       <td id="T_58703_row0_col3" class="data row0 col3" >273.101190</td>
#       <td id="T_58703_row0_col4" class="data row0 col4" >272.626488</td>
#       <td id="T_58703_row0_col5" class="data row0 col5" >272.151786</td>
#       <td id="T_58703_row0_col6" class="data row0 col6" >271.677083</td>
#     </tr>
#     <tr>
#       <th id="T_58703_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_58703_row1_col0" class="data row1 col0" >199.620238</td>
#       <td id="T_58703_row1_col1" class="data row1 col1" >199.240476</td>
#       <td id="T_58703_row1_col2" class="data row1 col2" >198.860714</td>
#       <td id="T_58703_row1_col3" class="data row1 col3" >198.480952</td>
#       <td id="T_58703_row1_col4" class="data row1 col4" >198.101190</td>
#       <td id="T_58703_row1_col5" class="data row1 col5" >197.721429</td>
#       <td id="T_58703_row1_col6" class="data row1 col6" >197.341667</td>
#     </tr>
#     <tr>
#       <th id="T_58703_level0_row2" class="row_heading level0 row2" >60</th>
#       <td id="T_58703_row2_col0" class="data row2 col0" >149.683532</td>
#       <td id="T_58703_row2_col1" class="data row2 col1" >149.367063</td>
#       <td id="T_58703_row2_col2" class="data row2 col2" >149.050595</td>
#       <td id="T_58703_row2_col3" class="data row2 col3" >148.734127</td>
#       <td id="T_58703_row2_col4" class="data row2 col4" >148.417659</td>
#       <td id="T_58703_row2_col5" class="data row2 col5" >148.101190</td>
#       <td id="T_58703_row2_col6" class="data row2 col6" >147.784722</td>
#     </tr>
#     <tr>
#       <th id="T_58703_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_58703_row3_col0" class="data row3 col0" >114.014456</td>
#       <td id="T_58703_row3_col1" class="data row3 col1" >113.743197</td>
#       <td id="T_58703_row3_col2" class="data row3 col2" >113.471939</td>
#       <td id="T_58703_row3_col3" class="data row3 col3" >113.200680</td>
#       <td id="T_58703_row3_col4" class="data row3 col4" >112.929422</td>
#       <td id="T_58703_row3_col5" class="data row3 col5" >112.658163</td>
#       <td id="T_58703_row3_col6" class="data row3 col6" >112.386905</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by dividend vs. selling_price</h2>
# <style type="text/css">
# #T_a7232_row0_col0, #T_a7232_row1_col0, #T_a7232_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a7232_row0_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_a7232_row0_col2, #T_a7232_row1_col2, #T_a7232_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a7232_row1_col1, #T_a7232_row2_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# </style>
# <table id="T_a7232">
#   <caption>Annual ROI - dividend vs. selling_price</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7232_level0_col0" class="col_heading level0 col0" >100</th>
#       <th id="T_a7232_level0_col1" class="col_heading level0 col1" >150</th>
#       <th id="T_a7232_level0_col2" class="col_heading level0 col2" >200</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dividend</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7232_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_a7232_row0_col0" class="data row0 col0" >88.078214</td>
#       <td id="T_a7232_row0_col1" class="data row0 col1" >183.018690</td>
#       <td id="T_a7232_row0_col2" class="data row0 col2" >277.959166</td>
#     </tr>
#     <tr>
#       <th id="T_a7232_level0_row1" class="row_heading level0 row1" >200</th>
#       <td id="T_a7232_row1_col0" class="data row1 col0" >88.438761</td>
#       <td id="T_a7232_row1_col1" class="data row1 col1" >183.379238</td>
#       <td id="T_a7232_row1_col2" class="data row1 col2" >278.319714</td>
#     </tr>
#     <tr>
#       <th id="T_a7232_level0_row2" class="row_heading level0 row2" >300</th>
#       <td id="T_a7232_row2_col0" class="data row2 col0" >88.799309</td>
#       <td id="T_a7232_row2_col1" class="data row2 col1" >183.739785</td>
#       <td id="T_a7232_row2_col2" class="data row2 col2" >278.680261</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by dividend vs. costs</h2>
# <style type="text/css">
# #T_d06a2_row0_col0, #T_d06a2_row1_col1, #T_d06a2_row2_col2 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_d06a2_row0_col1, #T_d06a2_row1_col2, #T_d06a2_row2_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_d06a2_row0_col2, #T_d06a2_row1_col3, #T_d06a2_row2_col4 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_d06a2_row0_col3, #T_d06a2_row1_col4, #T_d06a2_row2_col5 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_d06a2_row0_col4, #T_d06a2_row1_col5, #T_d06a2_row2_col6 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_d06a2_row0_col5, #T_d06a2_row1_col6 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_d06a2_row0_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d06a2_row1_col0, #T_d06a2_row2_col1 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_d06a2_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d06a2">
#   <caption>Annual ROI - dividend vs. costs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d06a2_level0_col0" class="col_heading level0 col0" >300</th>
#       <th id="T_d06a2_level0_col1" class="col_heading level0 col1" >400</th>
#       <th id="T_d06a2_level0_col2" class="col_heading level0 col2" >500</th>
#       <th id="T_d06a2_level0_col3" class="col_heading level0 col3" >600</th>
#       <th id="T_d06a2_level0_col4" class="col_heading level0 col4" >700</th>
#       <th id="T_d06a2_level0_col5" class="col_heading level0 col5" >800</th>
#       <th id="T_d06a2_level0_col6" class="col_heading level0 col6" >900</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dividend</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d06a2_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_d06a2_row0_col0" class="data row0 col0" >184.100333</td>
#       <td id="T_d06a2_row0_col1" class="data row0 col1" >183.739785</td>
#       <td id="T_d06a2_row0_col2" class="data row0 col2" >183.379238</td>
#       <td id="T_d06a2_row0_col3" class="data row0 col3" >183.018690</td>
#       <td id="T_d06a2_row0_col4" class="data row0 col4" >182.658142</td>
#       <td id="T_d06a2_row0_col5" class="data row0 col5" >182.297594</td>
#       <td id="T_d06a2_row0_col6" class="data row0 col6" >181.937046</td>
#     </tr>
#     <tr>
#       <th id="T_d06a2_level0_row1" class="row_heading level0 row1" >200</th>
#       <td id="T_d06a2_row1_col0" class="data row1 col0" >184.460881</td>
#       <td id="T_d06a2_row1_col1" class="data row1 col1" >184.100333</td>
#       <td id="T_d06a2_row1_col2" class="data row1 col2" >183.739785</td>
#       <td id="T_d06a2_row1_col3" class="data row1 col3" >183.379238</td>
#       <td id="T_d06a2_row1_col4" class="data row1 col4" >183.018690</td>
#       <td id="T_d06a2_row1_col5" class="data row1 col5" >182.658142</td>
#       <td id="T_d06a2_row1_col6" class="data row1 col6" >182.297594</td>
#     </tr>
#     <tr>
#       <th id="T_d06a2_level0_row2" class="row_heading level0 row2" >300</th>
#       <td id="T_d06a2_row2_col0" class="data row2 col0" >184.821429</td>
#       <td id="T_d06a2_row2_col1" class="data row2 col1" >184.460881</td>
#       <td id="T_d06a2_row2_col2" class="data row2 col2" >184.100333</td>
#       <td id="T_d06a2_row2_col3" class="data row2 col3" >183.739785</td>
#       <td id="T_d06a2_row2_col4" class="data row2 col4" >183.379238</td>
#       <td id="T_d06a2_row2_col5" class="data row2 col5" >183.018690</td>
#       <td id="T_d06a2_row2_col6" class="data row2 col6" >182.658142</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by selling_price vs. costs</h2>
# <style type="text/css">
# #T_c236c_row0_col0, #T_c236c_row0_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_c236c_row0_col2, #T_c236c_row0_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_c236c_row0_col4, #T_c236c_row0_col5, #T_c236c_row0_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c236c_row1_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_c236c_row1_col1, #T_c236c_row1_col2 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_c236c_row1_col3, #T_c236c_row1_col4, #T_c236c_row1_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_c236c_row1_col6 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_c236c_row2_col0, #T_c236c_row2_col1, #T_c236c_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c236c_row2_col3, #T_c236c_row2_col4 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_c236c_row2_col5, #T_c236c_row2_col6 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c236c">
#   <caption>Annual ROI - selling_price vs. costs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c236c_level0_col0" class="col_heading level0 col0" >300</th>
#       <th id="T_c236c_level0_col1" class="col_heading level0 col1" >400</th>
#       <th id="T_c236c_level0_col2" class="col_heading level0 col2" >500</th>
#       <th id="T_c236c_level0_col3" class="col_heading level0 col3" >600</th>
#       <th id="T_c236c_level0_col4" class="col_heading level0 col4" >700</th>
#       <th id="T_c236c_level0_col5" class="col_heading level0 col5" >800</th>
#       <th id="T_c236c_level0_col6" class="col_heading level0 col6" >900</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >selling_price</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c236c_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_c236c_row0_col0" class="data row0 col0" >89.520405</td>
#       <td id="T_c236c_row0_col1" class="data row0 col1" >89.159857</td>
#       <td id="T_c236c_row0_col2" class="data row0 col2" >88.799309</td>
#       <td id="T_c236c_row0_col3" class="data row0 col3" >88.438761</td>
#       <td id="T_c236c_row0_col4" class="data row0 col4" >88.078214</td>
#       <td id="T_c236c_row0_col5" class="data row0 col5" >87.717666</td>
#       <td id="T_c236c_row0_col6" class="data row0 col6" >87.357118</td>
#     </tr>
#     <tr>
#       <th id="T_c236c_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_c236c_row1_col0" class="data row1 col0" >184.460881</td>
#       <td id="T_c236c_row1_col1" class="data row1 col1" >184.100333</td>
#       <td id="T_c236c_row1_col2" class="data row1 col2" >183.739785</td>
#       <td id="T_c236c_row1_col3" class="data row1 col3" >183.379238</td>
#       <td id="T_c236c_row1_col4" class="data row1 col4" >183.018690</td>
#       <td id="T_c236c_row1_col5" class="data row1 col5" >182.658142</td>
#       <td id="T_c236c_row1_col6" class="data row1 col6" >182.297594</td>
#     </tr>
#     <tr>
#       <th id="T_c236c_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_c236c_row2_col0" class="data row2 col0" >279.401357</td>
#       <td id="T_c236c_row2_col1" class="data row2 col1" >279.040809</td>
#       <td id="T_c236c_row2_col2" class="data row2 col2" >278.680261</td>
#       <td id="T_c236c_row2_col3" class="data row2 col3" >278.319714</td>
#       <td id="T_c236c_row2_col4" class="data row2 col4" >277.959166</td>
#       <td id="T_c236c_row2_col5" class="data row2 col5" >277.598618</td>
#       <td id="T_c236c_row2_col6" class="data row2 col6" >277.238070</td>
#     </tr>
#   </tbody>
# </table>
# {('share_no',
#   'buying_price'): <pandas.io.formats.style.Styler at 0x2a5db192d60>,
#  ('share_no', 'dividend'): <pandas.io.formats.style.Styler at 0x2a5db387730>,
#  ('share_no',
#   'selling_price'): <pandas.io.formats.style.Styler at 0x2a5d8c45eb0>,
#  ('share_no', 'costs'): <pandas.io.formats.style.Styler at 0x2a5db2fd970>,
#  ('buying_price',
#   'dividend'): <pandas.io.formats.style.Styler at 0x2a5d8c45e80>,
#  ('buying_price',
#   'selling_price'): <pandas.io.formats.style.Styler at 0x2a5d8c020a0>,
#  ('buying_price', 'costs'): <pandas.io.formats.style.Styler at 0x2a5db35dc40>,
#  ('dividend',
#   'selling_price'): <pandas.io.formats.style.Styler at 0x2a5d8b1bf10>,
#  ('dividend', 'costs'): <pandas.io.formats.style.Styler at 0x2a5db30b3d0>,
#  ('selling_price', 'costs'): <pandas.io.formats.style.Styler at 0x2a5d8bcd040>}

# %% [markdown]
# ## 8. Identify best-case investment scenario

# %%
@dataclass
class ModelInputs:
    share_no : int = 600
    buying_price: int = 20
    dividend: int = 800
    selling_price: int = 22
    costs: int = 100
        
model_data = ModelInputs()
model_data
# Out:
# ModelInputs(share_no=600, buying_price=20, dividend=800, selling_price=22, costs=100)

# %%
def annualized_roi_per_year_for_required_roi(data: ModelInputs):
    year = 0
    prior_roi = 0
    
    for year in range(19):
        year = year + 1        
        net_return = (data.selling_price - data.buying_price) * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no

        roi = prior_roi + ((net_return)/(cost_of_investment))*100 
        annual_roi = ((1 + (roi/100))**(1/year)-1)*100
        
        prior_roi = roi 
    print(f'The annualized ROI at year {year} reaches {annual_roi}% for total shares of {model_data.share_no}\
    with a buying price of {model_data.buying_price}, selling price of {model_data.selling_price}')
    
annualized_roi_per_year_for_required_roi(model_data)
# Out:
# The annualized ROI at year 19 reaches 7.580841850996478% for total shares of 600    with a buying price of 20, selling price of 22
